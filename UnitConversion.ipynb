# %% [markdown]
# # Unit Conversion

# %%
import numpy as np
import string

# %%
"""
Convert any volume measurement from the current unit to milliliters
"""
def convert_to_ml(num, unit):
    table = str.maketrans({key: None for key in string.punctuation})
    unit = unit.translate(table).lower().strip()
    the_unit = ""
    
    if "gal" in unit:
        the_unit = "gallon"
        weight = 3785.41
    elif "qu" in unit or "qt" in unit:
        the_unit = "quart"
        weight = 946.353 
    elif "pt" in unit or "pint" in unit:
        the_unit = "pint"
        weight = 473.176
    elif "cup" in unit:
        the_unit = "cup"
        weight = 240
    elif "fl" in unit or "oz" in unit:
        the_unit = "fl oz"
        weight = 29.5735
    elif "tbsp" in unit or "table" in unit:
        the_unit = "tablespoon"
        weight = 14.7868
    elif "tsp" in unit or "tea" in unit:
        the_unit = "teaspoon"
        weight = 4.92892
    elif "m3" in unit or "cubic meter" in unit or "meter" in unit:
        the_unit = "cubic meter"
        weight = 1e6
    elif "ml" in unit or "milli" in unit:
        the_unit = "milliliter"
        weight = 1
    elif "liter" in unit or "l" == unit:
        the_unit = "liter"
        weight = 1000
    elif "cubic foot" in unit or "f3" in unit:
        the_unit = "cubic foot"
        weight = 28316.8
    elif "cubic inch" in unit or "in3" in unit:
        the_unit = "cubic inch"
        weight = 16.3871
        
    output = weight * num
    print('Converted', the_unit, 'to milliliters')
    return(output)

# %%
"""
Convert any mass measurement to grams
"""
def convert_to_grams(num, unit):
    table = str.maketrans({key: None for key in string.punctuation})
    unit = unit.translate(table).lower().strip()
    the_unit = ""
    
    if "metric ton" in unit or "mt" in unit or "m t" in unit:
        the_unit = "metric ton"
        weight = 1e6
    elif "kilo" in unit or "kg" in unit:
        the_unit = "kilogram"
        weight = 1000
    elif "gram" in unit or "g" == unit:
        the_unit = "gram"
        weight = 1
    elif "milli" in unit or "mg" in unit:
        the_unit = "milligram"
        weight = 0.001
    elif "micro" in unit or "μg" in unit or "mcg" in unit:
        the_unit = "microgram"
        weight = 1e-6
    elif "ton" in unit or "t" == unit:
        the_unit = "ton"
        weight = 907185
    elif "stone" in unit or "st" == unit:
        the_unit = "stone"
        weight = 6350.29
    elif "pound" in unit or "lb" in unit:
        the_unit = "pound"
        weight = 453.592
    elif "ounce" in unit or "ozs" in unit or "oz" in unit:
        the_unit = "ounces"
        weight = 28.3495
        
    output = weight * num
    print('Converted', the_unit, 'to grams')
    return(output)

# %%
"""
Convert the unit, and let the code decide whether the measurement is
volume or mass
"""
def convert(num, unit):
    # Eliminate punctuation and notion of case
    table = str.maketrans({key: None for key in string.punctuation})
    unit = unit.translate(table).lower().strip()
    the_unit = ""
    weight = 0
    volume = False
    mass = False
    
    # Testing for volume
    if "gal" in unit:
        the_unit = "gallon"
        weight = 3785.41
        volume = True
    elif "qu" in unit or "qt" in unit or "q" in unit:
        the_unit = "quart"
        weight = 946.353
        volume = True
    elif "pt" in unit or "pint" in unit:
        the_unit = "pint"
        weight = 473.176
        volume = True
    elif "cup" in unit:
        the_unit = "cup"
        weight = 240
        volume = True
    elif "fl" in unit or "oz" in unit:
        the_unit = "fl oz"
        weight = 29.5735
        volume = True
    elif "tbsp" in unit or "table" in unit:
        the_unit = "tablespoon"
        weight = 14.7868
        volume = True
    elif "tsp" in unit or "tea" in unit:
        the_unit = "teaspoon"
        weight = 4.92892
        volume = True
    elif "m3" in unit or "cubic meter" in unit or "meter" in unit:
        the_unit = "cubic meter"
        weight = 1e6
        volume = True
    elif "ml" in unit or "milli" in unit:
        the_unit = "milliliter"
        weight = 1
        volume = True
    elif "liter" in unit or "l" == unit:
        the_unit = "liter"
        weight = 1000
        volume = True
    elif "cubic foot" in unit or "f3" in unit:
        the_unit = "cubic foot"
        weight = 28316.8
        volume = True
    elif "cubic inch" in unit or "in3" in unit:
        the_unit = "cubic inch"
        weight = 16.3871
        volume = True
      
    # Testing for mass
    elif "metric ton" in unit or "mt" in unit or "m t" in unit:
        the_unit = "metric ton"
        weight = 1e6
        mass = True
    elif "kilo" in unit or "kg" in unit:
        the_unit = "kilogram"
        weight = 1000
        mass = True
    elif "gram" in unit or "g" == unit:
        the_unit = "gram"
        weight = 1
        mass = True
    elif "milli" in unit or "mg" in unit:
        the_unit = "milligram"
        weight = 0.001
        mass = True
    elif "micro" in unit or "μg" in unit or "mcg" in unit:
        the_unit = "microgram"
        weight = 1e-6
        mass = True
    elif "ton" in unit or "t" == unit:
        the_unit = "ton"
        weight = 907185
        mass = True
    elif "stone" in unit or "st" == unit:
        the_unit = "stone"
        weight = 6350.29
        mass = True
    elif "pound" in unit or "lb" in unit:
        the_unit = "pound"
        weight = 453.592
        mass = True
    elif "ounce" in unit or "ozs" in unit or "oz" in unit:
        the_unit = "ounces"
        weight = 28.3495
        mass = True
        
    # Convert the unit
    output = weight * num
    if volume:
        print('Converted', the_unit, 'to milliliters')
    else:
        print('Converted', the_unit, 'to grams')
    print(output)
    return(output)

# %% [markdown]
# ## Conversion Testing

# %%
import random

# %%
# List of some expected input units to the function
units = ['oz', 'ounces', 'ounce', 'gram', 'grams', 'ml', 'l', 'pound', 'lb',
        'ozs', 'stone', 'st', 's.t.', 'milliliters', 'ton', 't', 'micrograms',
        'microgram', 'kilograms', 'kg', 'kilogram', 'metric ton', 'mt', 'm.t',
        'metric tonne', 'cubic inch', 'cubic inches', 'cubic feet', 'f3', 'in3',
        'liter', 'cubic meter', 'm3', 'tsp', 'teaspoons', 'teaspoon', 'tsbp',
        'tablespoons', 'cup', 'cups', 'c', 'floz', 'fluid oz', 'fluid ounces', 
        'quart', 'qu', 'qt', 'pint', 'pt', 'gallons', 'gal']

tests = 20
# list of random measurements
nums = [random.randint(1, 1000) for i in range(tests)]
# list of random indices to choose units
indices = [random.randint(0, len(units)) for i in range(tests)]

# %%
for i in range(tests):
    print("INPUT     Num:", nums[i], ', Indices:', units[indices[i]])
    convert(nums[i], units[indices[i]])
    print()
# Out:
# INPUT     Num: 848 , Indices: fluid oz
# Converted fl oz to milliliters
# 25078.327999999998
#
# INPUT     Num: 936 , Indices: cups
# Converted cup to milliliters
# 224640
#
# INPUT     Num: 740 , Indices: teaspoon
# Converted teaspoon to milliliters
# 3647.4008
#
# INPUT     Num: 462 , Indices: qu
# Converted quart to milliliters
# 437215.08599999995
#
# INPUT     Num: 824 , Indices: m.t
# Converted metric ton to grams
# 824000000.0
#
# INPUT     Num: 198 , Indices: gallons
# Converted gallon to milliliters
# 749511.1799999999
#
# INPUT     Num: 481 , Indices: cubic inches
# Converted cubic inch to milliliters
# 7882.1951
#
# INPUT     Num: 841 , Indices: oz
# Converted fl oz to milliliters
# 24871.3135
#
# INPUT     Num: 803 , Indices: ounce
# Converted ounces to grams
# 22764.6485
#
# INPUT     Num: 810 , Indices: metric ton
# Converted metric ton to grams
# 810000000.0
#
# INPUT     Num: 593 , Indices: gram
# Converted gram to grams
# 593
#
# INPUT     Num: 848 , Indices: teaspoons
# Converted teaspoon to milliliters
# 4179.72416
#
# INPUT     Num: 362 , Indices: s.t.
# Converted stone to grams
# 2298804.98
#
# INPUT     Num: 330 , Indices: cubic inch
# Converted cubic inch to milliliters
# 5407.743
#
# INPUT     Num: 476 , Indices: tablespoons
# Converted tablespoon to milliliters
# 7038.516799999999
#
# INPUT     Num: 737 , Indices: pt
# Converted pint to milliliters
# 348730.712
#
# INPUT     Num: 449 , Indices: floz
# Converted fl oz to milliliters
# 13278.5015
#
# INPUT     Num: 1000 , Indices: ml
# Converted milliliter to milliliters
# 1000
#
# INPUT     Num: 741 , Indices: mt
# Converted metric ton to grams
# 741000000.0
#
# INPUT     Num: 880 , Indices: cups
# Converted cup to milliliters
# 211200
